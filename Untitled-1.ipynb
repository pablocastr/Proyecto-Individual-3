# %%
import pandas as pd
import seaborn as sns

# %%
# 2 KPI
# Considerar la cantidad de aumento o disminución anual nacional del total de accesos a banda ancha y angosta

# %%
accesosabandaanchayangosxprov1=pd.read_csv("accesos a banda ancha y angos x prov - Copy.csv")
accesosabandaanchayangosxprov1.head(15)
# Out:
#      Año  Trimestre        Provincia  Banda ancha fija Dial up    Total
# 0   2022          2     Buenos Aires           4660984    6199  4667183
# 1   2022          2  Capital Federal           1534626    2145  1536771
# 2   2022          2        Catamarca             67007       1    67008
# 3   2022          2            Chaco            143559       5   143564
# 4   2022          2           Chubut            161901     904   162805
# 5   2022          2          Córdoba           1026367      68  1026435
# 6   2022          2       Corrientes            144993       4   144997
# 7   2022          2       Entre Ríos            269330      22   269352
# 8   2022          2          Formosa             67881     - 0    67881
# 9   2022          2            Jujuy            115314     - 0   115314
# 10  2022          2         La Pampa            111356     171   111527
# 11  2022          2         La Rioja             86026       4    86030
# ...

# %%
accesosabandaanchayangosxprov1=accesosabandaanchayangosxprov1.drop(columns=["Trimestre","Banda ancha fija","Dial up"])

# %%
accesosabandaanchayangosxprov1.to_csv("KPI2.csv")

# %%
accesosabandaanchayangosxprov1.head(35)
# Out:
#      Año            Provincia    Total
# 0   2022         Buenos Aires  4667183
# 1   2022      Capital Federal  1536771
# 2   2022            Catamarca    67008
# 3   2022                Chaco   143564
# 4   2022               Chubut   162805
# 5   2022              Córdoba  1026435
# 6   2022           Corrientes   144997
# 7   2022           Entre Ríos   269352
# 8   2022              Formosa    67881
# 9   2022                Jujuy   115314
# 10  2022             La Pampa   111527
# 11  2022             La Rioja    86030
# 12  2022              Mendoza   279562
# 13  2022             Misiones   178813
# 14  2022              Neuquén   161968
# 15  2022            Río Negro   159764
# 16  2022                Salta   203177
# 17  2022             San Juan   100407
# 18  2022             San Luis   121741
# 19  2022           Santa Cruz    49185
# 20  2022             Santa Fe   878859
# 21  2022  Santiago Del Estero   118044
# 22  2022     Tierra Del Fuego    53770
# ...

# %%
accesosabandaanchayangosxprov1.isnull().sum()
# Out:
# Año          0
# Provincia    0
# Total        0
# dtype: int64

# %%
accesosabandaanchayangosxprov1.Total.describe()
# Out:
# count    7.920000e+02
# mean     3.446130e+05
# std      7.383715e+05
# min      1.304600e+04
# 25%      5.200825e+04
# 50%      1.030125e+05
# 75%      1.755502e+05
# max      4.667183e+06
# Name: Total, dtype: float64

# %%
accesosabandaanchayangosxprov1.Total.sort_values()
# Out:
# 762      13046
# 786      13055
# 738      13147
# 642      13218
# 666      13219
#         ...
# 96     4132351
# 72     4251609
# 48     4509157
# 24     4555424
# 0      4667183
# Name: Total, Length: 792, dtype: int64

# %%
accesosabandaanchayangosxprov1.Total.hist()
# Out:
# <AxesSubplot: >

# %%
accesosabandaanchayangosxprov1.Año.hist()
# Out:
# <AxesSubplot: >

# %%
#Plot histograms of numerical data
# %matplotlib inline
import matplotlib.pyplot as plt
accesosabandaanchayangosxprov1.Año.hist(bins = 50, figsize = (20,15))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 3 KPI
# Estudiar la cantidad de aumento o disminución trimestral de ingresos por servicios de internet fijo.

# %%
ingrtrimxservintfijo=pd.read_csv("ingr trim x serv int fijo.csv")
ingrtrimxservintfijo.head(15)
# Out:
#      Año  Trimestre  Ingresos (miles de pesos)        Periodo
# 0   2022          2                   60942843   Abr-Jun 2022
# 1   2022          1                   56195811   Ene-Mar 2022
# 2   2021          4                   45467887   Oct-Dic 2021
# 3   2021          3                   42999944  Jul-Sept 2021
# 4   2021          2                   38239667   Abr-Jun 2021
# 5   2021          1                   36676371   Ene-Mar 2021
# 6   2020          4                   33539703   Oct-Dic 2020
# 7   2020          3                   31997445  Jul-Sept 2020
# 8   2020          2                   32102476   Abr-Jun 2020
# 9   2020          1                   29946216   Ene-Mar 2020
# 10  2019          4                   24169251   Oct-Dic 2019
# 11  2019          3                   21652748  Jul-Sept 2019
# 12  2019          2                   20743118   Abr-Jun 2019
# 13  2019          1                   20207414   Ene-Mar 2019
# ...

# %%
# 1 KPI
# Evaluar el aumento o disminución de la variación porcentual trimestral del servicio de internet, cada 100 hogares por provincia.

# %%
penetrintfijocada100hog=pd.read_csv("penetr int fijo cada 100 hog.csv")
penetrintfijocada100hog.head(15)
# Out:
#      Año  Trimestre        Provincia Accesos por cada 100 hogares
# 0   2022          2     Buenos Aires                        77,58
# 1   2022          2  Capital Federal                       121,31
# 2   2022          2        Catamarca                         62,4
# 3   2022          2            Chaco                        43,79
# 4   2022          2           Chubut                        83,19
# 5   2022          2          Córdoba                        87,48
# 6   2022          2       Corrientes                        48,35
# 7   2022          2       Entre Ríos                         63,9
# 8   2022          2          Formosa                        43,42
# 9   2022          2            Jujuy                        57,32
# 10  2022          2         La Pampa                        92,98
# 11  2022          2         La Rioja                        80,14
# 12  2022          2          Mendoza                        49,39
# ...

# %%
penetrintfijocada100hog = penetrintfijocada100hog.rename(columns={'Accesos por cada 100 hogares':'accesos'})

# %%
penetrintfijocada100hog.accesos.replace(",",".",inplace=True,regex=True)

# %%
penetrintfijocada100hog.head(15)
# Out:
#      Año  Trimestre        Provincia accesos
# 0   2022          2     Buenos Aires   77.58
# 1   2022          2  Capital Federal  121.31
# 2   2022          2        Catamarca    62.4
# 3   2022          2            Chaco   43.79
# 4   2022          2           Chubut   83.19
# 5   2022          2          Córdoba   87.48
# 6   2022          2       Corrientes   48.35
# 7   2022          2       Entre Ríos    63.9
# 8   2022          2          Formosa   43.42
# 9   2022          2            Jujuy   57.32
# 10  2022          2         La Pampa   92.98
# 11  2022          2         La Rioja   80.14
# 12  2022          2          Mendoza   49.39
# 13  2022          2         Misiones      51
# 14  2022          2          Neuquén   80.02

# %%
penetrintfijocada100hog.to_csv("KPI1.csv")

# %%
# cuarto KPI
# Verificar el aumento o disminución anual nacional de la velocidad media de bajada en Mbps.

# %%
velmediadbajadaintfijo=pd.read_csv("vel media d bajada int fijo.csv")
velmediadbajadaintfijo.head(15)
# Out:
#       Año  Trimestre  Mbps (Media de bajada)    Trimestre.1
# 2022    2         58                      44   Abr-Jun 2022
# 2022    1         55                      11   Ene-Mar 2022
# 2021    4         52                      34   Oct-Dic 2021
# 2021    3         48                      46  Jul-Sept 2021
# 2021    2         45                      63   Abr-Jun 2021
# 2021    1         43                      11   Ene-Mar 2021
# 2020    4         42                      36   Oct-Dic 2020
# 2020    3         40                      67  Jul-Sept 2020
# 2020    2         38                      32   Abr-Jun 2020
# 2020    1         37                      52   Ene-Mar 2020
# 2019    4         28                      26   Oct-Dic 2019
# 2019    3         24                      18  Jul-Sept 2019
# 2019    2         20                      33   Abr-Jun 2019
# 2019    1         17                      38   Ene-Mar 2019
# 2018    4         15                      95   Oct-Dic 2018

# %%
velmediadbajadaintfijo = velmediadbajadaintfijo.rename(columns={'Mbps (Media de bajada)':'mbpsmedia'})

# %%
velmediadbajadaintfijo.mbpsmedia.replace(",",".",inplace=True,regex=True)

# %%
velmediadbajadaintfijo.head(15)
# Out:
#      Año  Trimestre mbpsmedia    Trimestre.1
# 0   2022          2     58.44   Abr-Jun 2022
# 1   2022          1     55.11   Ene-Mar 2022
# 2   2021          4     52.34   Oct-Dic 2021
# 3   2021          3     48.46  Jul-Sept 2021
# 4   2021          2     45.63   Abr-Jun 2021
# 5   2021          1     43.11   Ene-Mar 2021
# 6   2020          4     42.36   Oct-Dic 2020
# 7   2020          3     40.67  Jul-Sept 2020
# 8   2020          2     38.32   Abr-Jun 2020
# 9   2020          1     37.52   Ene-Mar 2020
# 10  2019          4     28.26   Oct-Dic 2019
# 11  2019          3     24.18  Jul-Sept 2019
# 12  2019          2     20.33   Abr-Jun 2019
# 13  2019          1     17.38   Ene-Mar 2019
# 14  2018          4     15.95   Oct-Dic 2018

# %%
velmediadbajadaintfijo.to_csv("KPI4.csv")
